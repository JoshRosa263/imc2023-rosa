# %% [markdown]
# <a href="https://colab.research.google.com/github/JoshRosa263/imc2023-rosa/blob/main/Homework_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import numpy as np
import matplotlib.pylab as plt
import librosa
import librosa.display

# %%
# open the audio file avm2.wav with librosa.load()
file = 'imc2023/audioFiles/trumpet.wav'
samplingRate = 44100
sig, sr = librosa.load(file,mono=True,sr=samplingRate)

# %%
# plot time domain representation of the signal
plt.plot(sig)

# %%
#adjust the x-axis to represent time
time=np.arange(0,sig.shape[0])/sr
plt.plot(time,sig)

# %%
# scale the y-axis to represent amplitude
excursion=max(abs(sig))
sigNew = sig / excursion
plt.plot(time,sigNew)

# %%
# add x and y labels
plt.plot(time,sigNew)
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
#opening The audio File Trumpet.wav with librosa.load() with 441 sR
file = 'imc2023/audioFiles/trumpet.wav'
samplingRate = 441
sig, sr = librosa.load(file,mono=True,sr=samplingRate)

# %%
# plot time domain representation of the signal
plt.plot(sig)

# %%
#plot with Time on the x-axis 
time=np.arange(0,sig.shape[0])/sr
plt.plot(time,sig)

# %%
#Plot with Amplitude on the Y-axis
excursion=max(abs(sig))
sigNew = sig / excursion
plt.plot(time,sigNew)

# %%
#Plot with labels 
plt.plot(time,sigNew)
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')
